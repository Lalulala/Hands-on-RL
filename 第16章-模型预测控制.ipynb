# %%
import numpy as np
from scipy.stats import truncnorm
import gym
import itertools
import torch
import torch.nn as nn
import torch.nn.functional as F
import collections
import matplotlib.pyplot as plt


class CEM:
    def __init__(self, n_sequence, elite_ratio, fake_env, upper_bound,
                 lower_bound):
        self.n_sequence = n_sequence
        self.elite_ratio = elite_ratio
        self.upper_bound = upper_bound
        self.lower_bound = lower_bound
        self.fake_env = fake_env

    def optimize(self, state, init_mean, init_var):
        mean, var = init_mean, init_var
        X = truncnorm(-2, 2, loc=np.zeros_like(mean), scale=np.ones_like(var))
        state = np.tile(state, (self.n_sequence, 1))

        for _ in range(5):
            lb_dist, ub_dist = mean - self.lower_bound, self.upper_bound - mean
            constrained_var = np.minimum(
                np.minimum(np.square(lb_dist / 2), np.square(ub_dist / 2)),
                var)
            # 生成动作序列
            action_sequences = [X.rvs() for _ in range(self.n_sequence)
                                ] * np.sqrt(constrained_var) + mean
            # 计算每条动作序列的累积奖励
            returns = self.fake_env.propagate(state, action_sequences)[:, 0]
            # 选取累积奖励最高的若干条动作序列
            elites = action_sequences[np.argsort(
                returns)][-int(self.elite_ratio * self.n_sequence):]
            new_mean = np.mean(elites, axis=0)
            new_var = np.var(elites, axis=0)
            # 更新动作序列分布
            mean = 0.1 * mean + 0.9 * new_mean
            var = 0.1 * var + 0.9 * new_var

        return mean

# %% [markdown]
# truncated_normal_init实现了一个截断正态分布的初始化函数，其作用是用正态分布填充给定张量 t，同时确保生成的数值不会偏离均值过远。函数一开始调用 torch.nn.init.normal_ 在整个张量上进行正态分布初始化，使用给定的均值和标准差。
#
# 随后进入一个无限循环，在循环内部通过比较 t 中的每个元素是否小于 (mean - 2 * std) 或大于 (mean + 2 * std) 来构造一个布尔型条件张量 cond。这个条件张量用于标记出所有超出均值两倍标准差范围的元素。通过 torch.sum(cond) 来判断是否存在超出该范围的数值，如果没有（即和为0），则退出循环，表明所有数值均处于预期范围内。
#
# 如果存在偏离较大的值，则使用 torch.where 对张量进行更新。对于满足条件的部分，利用 torch.ones 创建一个形状相同的新张量，并对其进行正态初始化，生成新的合适数值；而那些已经位于合理范围内的元素则保持不变。整个过程不断重复，直到所有的值都落在预设的范围内，最后返回处理后的张量。
#
# t = torch.where代码行的作用是对张量 t 中的元素进行条件替换。具体来说，使用 torch.where 函数，根据布尔张量 cond 中的每个位置的值，决定选择哪个值来替换 t 中相应的元素。
#
# 当 cond 对应位置为 True 时，会选择第二个参数的值作为新的元素。这里第二个参数通过以下步骤生成：首先利用 torch.ones 创建一个与 t 形状相同、设备为 device 的全 1 张量；接着，这个张量被 torch.nn.init.normal_ 初始化，使得其元素服从均值为 mean、标准差为 std 的正态分布。也就是说，这部分元素被重新赋予一个符合正态分布的随机值。对于 cond 为 False 的位置，则保留原始 t 中的值。
#
# 这种做法常用于在张量初始化或更新过程中，对不符合某个条件的数值进行重新采样，从而确保所有元素都满足特定的分布要求。
#
# if type(m) == nn.Linear or isinstance(m, FCLayer):代码首先判断模块 m 是否为 nn.Linear 类型（严格匹配）或 FCLayer 类的实例（允许子类继承），以确定该模块需要进行特定的初始化操作。这种检查确保只有特定的层会应用后续的权重和偏置初始化。
#
# 接着，代码调用自定义的 truncated_normal_init 函数来初始化模块 m 的权重。这里传递的标准差 std 为 1/(2 * √(m._input_dim))，其中 m._input_dim 表示输入特征的维度。这种设计使得权重初始化的尺度能够根据层的输入维度进行适当的调整，以提高模型训练时的稳定性和收敛速度。
#
# 最后，通过调用 m.bias.data.fill_(0.0) 将偏置项的所有值填充为 0。这是一种常见的初始化策略，它确保在训练开始时偏置项不会引入额外的随机性，从而帮助模型在初期阶段表现出较为稳定的行为。

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device(
    "cpu")


class Swish(nn.Module):
    ''' Swish激活函数 '''
    def __init__(self):
        super(Swish, self).__init__()

    def forward(self, x):
        return x * torch.sigmoid(x)


def init_weights(m):
    ''' 初始化模型权重 '''
    def truncated_normal_init(t, mean=0.0, std=0.01):
        torch.nn.init.normal_(t, mean=mean, std=std)
        while True:
            cond = (t < mean - 2 * std) | (t > mean + 2 * std)
            if not torch.sum(cond):
                break
            
            t = torch.where(
                cond,
                torch.nn.init.normal_(torch.ones(t.shape, device=device),
                                      mean=mean,
                                      std=std), t)
        return t

    if type(m) == nn.Linear or isinstance(m, FCLayer):
        truncated_normal_init(m.weight, std=1 / (2 * np.sqrt(m._input_dim)))
        m.bias.data.fill_(0.0)


class FCLayer(nn.Module):
    ''' 集成之后的全连接层 '''
    def __init__(self, input_dim, output_dim, ensemble_size, activation):
        super(FCLayer, self).__init__()
        self._input_dim, self._output_dim = input_dim, output_dim
        self.weight = nn.Parameter(
            torch.Tensor(ensemble_size, input_dim, output_dim).to(device))
        self._activation = activation
        self.bias = nn.Parameter(
            torch.Tensor(ensemble_size, output_dim).to(device))

    def forward(self, x):
        #x 的形状为 (ensemble_size, batch_size, input_dim)。
        #self.weight 的形状为 (ensemble_size, input_dim, output_dim)。
        #self.bias 的形状为 (ensemble_size, output_dim)。
        #self.bias[:, None, :] 的形状为 (ensemble_size, 1, output_dim)。
        #torch.bmm(x, self.weight) 的形状为 (ensemble_size, batch_size, output_dim)。
        #返回值的形状为 (ensemble_size, batch_size, output_dim)。
        return self._activation(
            torch.add(torch.bmm(x, self.weight), self.bias[:, None, :]))

# %% [markdown]
# ## means均值是用label学习的，那么方差是用什么学习的？
#
# 在该模型中，方差（由 logvar 表示）并不是直接与某个具体的标签对应，而是作为模型不确定性的度量，通过整体损失函数间接学习得到。具体来说，损失函数中包含两部分对方差的约束：
#
# 在均方误差（MSE）部分，误差被乘以了 inverse_var（即 exp(-logvar)），这意味着模型可以通过调整 logvar 来动态控制误差的重要性。较大的预测不确定性（较高的 logvar）会使得对应样本的误差在损失中权重减小，从而允许模型在那些难以预测的样本上“容忍”较大的偏差。
#
# 另外，损失函数直接包含一个与 logvar 相关的项 var_loss，即对所有 logvar 的均值进行求和。这一项让模型不倾向于无限制地增大 logvar 来规避误差（否则总损失会增加），从而实现对预测不确定性范围的控制。
#
# 因此，方差（logvar）是通过上述损失函数的两部分共同学习得到的，目标是使得模型既能准确预测均值，又能合理地估计预测的不确定性。

# %%
class EnsembleModel(nn.Module):
    ''' 环境模型集成 '''
    def __init__(self,
                 state_dim,
                 action_dim,
                 ensemble_size=5,
                 learning_rate=1e-3):
        super(EnsembleModel, self).__init__()
        # 输出包括均值和方差,因此是状态与奖励维度之和的两倍
        self._output_dim = (state_dim + 1) * 2
        # 初始化均值和方差的上下限
        self._max_logvar = nn.Parameter((torch.ones(
            (1, self._output_dim // 2)).float() / 2).to(device),
                                        requires_grad=False)
        self._min_logvar = nn.Parameter((-torch.ones(
            (1, self._output_dim // 2)).float() * 10).to(device),
                                        requires_grad=False)

        self.layer1 = FCLayer(state_dim + action_dim, 200, ensemble_size,
                              Swish())
        self.layer2 = FCLayer(200, 200, ensemble_size, Swish())
        self.layer3 = FCLayer(200, 200, ensemble_size, Swish())
        self.layer4 = FCLayer(200, 200, ensemble_size, Swish())
        self.layer5 = FCLayer(200, self._output_dim, ensemble_size,
                              nn.Identity())
        self.apply(init_weights)  # 初始化环境模型中的参数
        self.optimizer = torch.optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x, return_log_var=False):
        #返回值的形状为 (ensemble_size, batch_size, output_dim)。
        ret = self.layer5(self.layer4(self.layer3(self.layer2(
            self.layer1(x)))))
        mean = ret[:, :, :self._output_dim // 2]
        # 在PETS算法中,将方差控制在最小值和最大值之间
        logvar = self._max_logvar - F.softplus(
            self._max_logvar - ret[:, :, self._output_dim // 2:])
        logvar = self._min_logvar + F.softplus(logvar - self._min_logvar)
        return mean, logvar if return_log_var else torch.exp(logvar)

    def loss(self, mean, logvar, labels, use_var_loss=True):
        inverse_var = torch.exp(-logvar)
        if use_var_loss:
            mse_loss = torch.mean(torch.mean(torch.pow(mean - labels, 2) *
                                             inverse_var,
                                             dim=-1),
                                  dim=-1)
            var_loss = torch.mean(torch.mean(logvar, dim=-1), dim=-1)
            total_loss = torch.sum(mse_loss) + torch.sum(var_loss)
        else:
            mse_loss = torch.mean(torch.pow(mean - labels, 2), dim=(1, 2))
            total_loss = torch.sum(mse_loss)
        return total_loss, mse_loss

    def train(self, loss):
        self.optimizer.zero_grad()
        #对方差进行边界控制
        loss += 0.01 * torch.sum(self._max_logvar) - 0.01 * torch.sum(
            self._min_logvar)
        loss.backward()
        self.optimizer.step()

# %%
class EnsembleDynamicsModel:
    ''' 环境模型集成,加入精细化的训练 '''
    def __init__(self, state_dim, action_dim, num_network=5):
        self._num_network = num_network
        self._state_dim, self._action_dim = state_dim, action_dim
        self.model = EnsembleModel(state_dim,
                                   action_dim,
                                   ensemble_size=num_network)
        self._epoch_since_last_update = 0

    def train(self,
              inputs,
              labels,
              batch_size=64,
              holdout_ratio=0.1,
              max_iter=20):
        # 设置训练集与验证集
        print('状态维度:', self._state_dim)
        print('动作维度:', self._action_dim)
        print(inputs.shape, labels.shape)
        permutation = np.random.permutation(inputs.shape[0])
        inputs, labels = inputs[permutation], labels[permutation]
        num_holdout = int(inputs.shape[0] * holdout_ratio)
        train_inputs, train_labels = inputs[num_holdout:], labels[num_holdout:]
        holdout_inputs, holdout_labels = inputs[:
                                                num_holdout], labels[:
                                                                     num_holdout]
        holdout_inputs = torch.from_numpy(holdout_inputs).float().to(device)
        holdout_labels = torch.from_numpy(holdout_labels).float().to(device)
        holdout_inputs = holdout_inputs[None, :, :].repeat(
            [self._num_network, 1, 1])
        holdout_labels = holdout_labels[None, :, :].repeat(
            [self._num_network, 1, 1])

        # 保留最好的结果
        self._snapshots = {i: (None, 1e10) for i in range(self._num_network)}

        for epoch in itertools.count():
            # 定义每一个网络的训练数据
            train_index = np.vstack([
                np.random.permutation(train_inputs.shape[0])
                for _ in range(self._num_network)
            ])
            # 所有真实数据都用来训练
            for batch_start_pos in range(0, train_inputs.shape[0], batch_size):
                batch_index = train_index[:, batch_start_pos:batch_start_pos +
                                          batch_size]
                train_input = torch.from_numpy(
                    train_inputs[batch_index]).float().to(device)
                train_label = torch.from_numpy(
                    train_labels[batch_index]).float().to(device)

                mean, logvar = self.model(train_input, return_log_var=True)
                loss, _ = self.model.loss(mean, logvar, train_label)
                self.model.train(loss)

            with torch.no_grad():
                mean, logvar = self.model(holdout_inputs, return_log_var=True)
                _, holdout_losses = self.model.loss(mean,
                                                    logvar,
                                                    holdout_labels,
                                                    use_var_loss=False)
                holdout_losses = holdout_losses.cpu()
                break_condition = self._save_best(epoch, holdout_losses)
                if break_condition or epoch > max_iter:  # 结束训练
                    break

    def _save_best(self, epoch, losses, threshold=0.1):
        updated = False
        for i in range(len(losses)):
            current = losses[i]
            _, best = self._snapshots[i]
            improvement = (best - current) / best
            if improvement > threshold:
                self._snapshots[i] = (epoch, current)
                updated = True
        self._epoch_since_last_update = 0 if updated else self._epoch_since_last_update + 1
        return self._epoch_since_last_update > 5

    def predict(self, inputs, batch_size=64):
        mean, var = [], []
        
        for i in range(0, inputs.shape[0], batch_size):
            input = torch.from_numpy(
                inputs[i:min(i +
                             batch_size, inputs.shape[0])]).float().to(device)
            print(input.shape)
            cur_mean, cur_var = self.model(input[None, :, :].repeat(
                [self._num_network, 1, 1]),
                                           return_log_var=False)
            mean.append(cur_mean.detach().cpu().numpy())
            var.append(cur_var.detach().cpu().numpy())
        return np.hstack(mean), np.hstack(var)

# %%
class FakeEnv:
    def __init__(self, model):
        self.model = model

    def step(self, obs, act):
        inputs = np.concatenate((obs, act), axis=-1)
        #inputs.shape:(50,4)
        #print('inputs.shape',inputs.shape)
        ensemble_model_means, ensemble_model_vars = self.model.predict(inputs)
        print('ensemble_model_means.shape',ensemble_model_means.shape)
        print('ensemble_model_vars.shape',ensemble_model_vars.shape)
        #模型的标签被设置为 (reward, next_obs - obs)
        ensemble_model_means[:, :, 1:] += obs.numpy()
        ensemble_model_stds = np.sqrt(ensemble_model_vars)
        ensemble_samples = ensemble_model_means + np.random.normal(
            size=ensemble_model_means.shape) * ensemble_model_stds

        num_models, batch_size, _ = ensemble_model_means.shape
        models_to_use = np.random.choice(
            [i for i in range(self.model._num_network)], size=batch_size)
        batch_inds = np.arange(0, batch_size)
        samples = ensemble_samples[models_to_use, batch_inds]
        rewards, next_obs = samples[:, :1], samples[:, 1:]
        return rewards, next_obs

    def propagate(self, obs, actions):
        with torch.no_grad():
            obs = np.copy(obs)
            total_reward = np.expand_dims(np.zeros(obs.shape[0]), axis=-1)
            #obs.shape:(50,3) actions.shape:(50,25)
            obs, actions = torch.as_tensor(obs), torch.as_tensor(actions)
            for i in range(actions.shape[1]):
                action = torch.unsqueeze(actions[:, i], 1)
                rewards, next_obs = self.step(obs, action)
                total_reward += rewards
                obs = torch.as_tensor(next_obs)
            return total_reward

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def size(self):
        return len(self.buffer)

    def return_all_samples(self):
        all_transitions = list(self.buffer)
        state, action, reward, next_state, done = zip(*all_transitions)
        return np.array(state), action, reward, np.array(next_state), done

# %%
class PETS:
    ''' PETS算法 '''
    def __init__(self, env, replay_buffer, n_sequence, elite_ratio,
                 plan_horizon, num_episodes):
        self._env = env
        self._env_pool = ReplayBuffer(buffer_size)
        # 状态维度 3
        obs_dim = env.observation_space.shape[0]
        # 动作维度 1
        self._action_dim = env.action_space.shape[0]
        self._model = EnsembleDynamicsModel(obs_dim, self._action_dim)
        self._fake_env = FakeEnv(self._model)
        self.upper_bound = env.action_space.high[0]
        self.lower_bound = env.action_space.low[0]

        self._cem = CEM(n_sequence, elite_ratio, self._fake_env,
                        self.upper_bound, self.lower_bound)
        self.plan_horizon = plan_horizon
        self.num_episodes = num_episodes

    def train_model(self):
        env_samples = self._env_pool.return_all_samples()
        obs = env_samples[0]
        actions = np.array(env_samples[1])
        rewards = np.array(env_samples[2]).reshape(-1, 1)
        next_obs = env_samples[3]
        inputs = np.concatenate((obs, actions), axis=-1)
        labels = np.concatenate((rewards, next_obs - obs), axis=-1)
        self._model.train(inputs, labels)

    def mpc(self):
        mean = np.tile((self.upper_bound + self.lower_bound) / 2.0,
                       self.plan_horizon)
        var = np.tile(
            np.square(self.upper_bound - self.lower_bound) / 16,
            self.plan_horizon)
        obs,_= self._env.reset()
        done, episode_return =  False, 0
        while not done:
            actions = self._cem.optimize(obs, mean, var)
            action = actions[:self._action_dim]  # 选取第一个动作
            # print('actions.shape:', actions.shape)
            # print('actions:', actions)
            # print('action.shape:', action.shape)
            # print('action:', action)
            next_obs, reward, done, truncated, info = self._env.step(action)
            done = done or truncated
            self._env_pool.add(obs, action, reward, next_obs, done)
            obs = next_obs
            episode_return += reward
            mean = np.concatenate([
                np.copy(actions)[self._action_dim:],
                np.zeros(self._action_dim)
            ])
        return episode_return

    def explore(self):
        obs,_= self._env.reset()
        done, episode_return =  False, 0
        while not done:
            action = self._env.action_space.sample()
            next_obs, reward, done, truncated, info = self._env.step(action)
            done = done or truncated
            self._env_pool.add(obs, action, reward, next_obs, done)
            obs = next_obs
            episode_return += reward
        return episode_return

    def train(self):
        return_list = []
        explore_return = self.explore()  # 先进行随机策略的探索来收集一条序列的数据
        print('episode: 1, return: %d' % explore_return)
        return_list.append(explore_return)

        for i_episode in range(self.num_episodes - 1):
            self.train_model()
            episode_return = self.mpc()
            return_list.append(episode_return)
            print('episode: %d, return: %d' % (i_episode + 2, episode_return))
        return return_list

# %%
buffer_size = 100000
n_sequence = 50
elite_ratio = 0.2
plan_horizon = 25
num_episodes = 10
env_name = 'Pendulum-v1'
env = gym.make(env_name)

replay_buffer = ReplayBuffer(buffer_size)
pets = PETS(env, replay_buffer, n_sequence, elite_ratio, plan_horizon,
            num_episodes)
return_list = pets.train()

episodes_list = list(range(len(return_list)))
plt.plot(episodes_list, return_list)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('PETS on {}'.format(env_name))
plt.show()

# episode: 1, return: -1062
# episode: 2, return: -1257
# episode: 3, return: -1792
# episode: 4, return: -1225
# episode: 5, return: -248
# episode: 6, return: -124
# episode: 7, return: -249
# episode: 8, return: -269
# episode: 9, return: -245
# episode: 10, return: -119
# Out:
# /usr/local/miniconda3/envs/HandsonRL/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# episode: 1, return: -1231
# 状态维度: 3
# 动作维度: 1
# (200, 4) (200, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# ...
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# torch.Size([5, 50, 4])
# torch.Size([5, 50, 4])
# ensemble_model_means.shape (5, 50, 4)
# ensemble_model_vars.shape (5, 50, 4)
# torch.Size([50, 4])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 12
#       9 replay_buffer = ReplayBuffer(buffer_size)
#      10 pets = PETS(env, replay_buffer, n_sequence, elite_ratio, plan_horizon,
#      11             num_episodes)
# ---> 12 return_list = pets.train()
#      14 episodes_list = list(range(len(return_list)))
#      15 plt.plot(episodes_list, return_list)
#
# Cell In[41], line 77, in PETS.train(self)
#      75 for i_episode in range(self.num_episodes - 1):
#      76     self.train_model()
# ---> 77     episode_return = self.mpc()
#      78     return_list.append(episode_return)
#      79     print('episode: %d, return: %d' % (i_episode + 2, episode_return))
#
# Cell In[41], line 40, in PETS.mpc(self)
#      38 done, episode_return =  False, 0
#      39 while not done:
# ---> 40     actions = self._cem.optimize(obs, mean, var)
#      41     action = actions[:self._action_dim]  # 选取第一个动作
#      42     # print('actions.shape:', actions.shape)
#      43     # print('actions:', actions)
#      44     # print('action.shape:', action.shape)
#      45     # print('action:', action)
#
# Cell In[35], line 35, in CEM.optimize(self, state, init_mean, init_var)
#      32 action_sequences = [X.rvs() for _ in range(self.n_sequence)
#      33                     ] * np.sqrt(constrained_var) + mean
#      34 # 计算每条动作序列的累积奖励
# ---> 35 returns = self.fake_env.propagate(state, action_sequences)[:, 0]
#      36 # 选取累积奖励最高的若干条动作序列
#      37 elites = action_sequences[np.argsort(
#      38     returns)][-int(self.elite_ratio * self.n_sequence):]
#
# Cell In[39], line 33, in FakeEnv.propagate(self, obs, actions)
#      31 for i in range(actions.shape[1]):
#      32     action = torch.unsqueeze(actions[:, i], 1)
# ---> 33     rewards, next_obs = self.step(obs, action)
#      34     total_reward += rewards
#      35     obs = torch.as_tensor(next_obs)
#
# Cell In[39], line 9, in FakeEnv.step(self, obs, act)
#       6 inputs = np.concatenate((obs, act), axis=-1)
#       7 #inputs.shape:(50,4)
#       8 #print('inputs.shape',inputs.shape)
# ----> 9 ensemble_model_means, ensemble_model_vars = self.model.predict(inputs)
#      10 print('ensemble_model_means.shape',ensemble_model_means.shape)
#      11 print('ensemble_model_vars.shape',ensemble_model_vars.shape)
#
# Cell In[38], line 88, in EnsembleDynamicsModel.predict(self, inputs, batch_size)
#      84 input = torch.from_numpy(
#      85     inputs[i:min(i +
#      86                  batch_size, inputs.shape[0])]).float().to(device)
#      87 print(input.shape)
# ---> 88 cur_mean, cur_var = self.model(input[None, :, :].repeat(
#      89     [self._num_network, 1, 1]),
#      90                                return_log_var=False)
#      91 print(cur_mean.shape)
#      92 print(cur_var.shape)
#
# File /usr/local/miniconda3/envs/HandsonRL/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/miniconda3/envs/HandsonRL/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[37], line 30, in EnsembleModel.forward(self, x, return_log_var)
#      28 def forward(self, x, return_log_var=False):
#      29     ret = self.layer5(self.layer4(self.layer3(self.layer2(
# ---> 30         self.layer1(x)))))
#      31     mean = ret[:, :, :self._output_dim // 2]
#      32     # 在PETS算法中,将方差控制在最小值和最大值之间
#
# File /usr/local/miniconda3/envs/HandsonRL/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/miniconda3/envs/HandsonRL/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[36], line 47, in FCLayer.forward(self, x)
#      45 def forward(self, x):
#      46     return self._activation(
# ---> 47         torch.add(torch.bmm(x, self.weight), self.bias[:, None, :]))
#
# KeyboardInterrupt:
